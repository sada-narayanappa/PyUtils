# %%
# %run "../../PyUtils/common.ipynb"
# Out:
# <style>
# body {
#     font-family: "Lucida Grande", "Lucida Sans Unicode", verdana, geneva, sans-serif;
#     font-size: 10pt;
# }
#
# CodeMirror-gutters {
#     border-right: 0px solid #ddd;
#     background-color: #f7f7f7;
#     white-space: nowrap;
# }
#
# div.output_subarea {
#     padding: 0.4em;
#     max-width: calc(100% - 0ex);
#     border: 1px #fefefe solid;
# }
#
#
# div#notebook{
#     font-size: 12px;
# }
# .CodeMirror {
#     font-size: 12px;
# }
#
# .imgs {
#     width: 250px;
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border: 0px gray;
# }
# .imgs1 {
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border-top: 1px solid gray;
#     border-bottom: 1px solid gray;
#     margin-right: 50px;
# }
# hr {
#     height:3px;
#     border:none;
#     color:#333;
#     background-color:#333;"
# }
# p {
#   margin: 10px auto;
#   padding: 6px 10px;
#   font-weight: 300;
# ...

# %%
'''
## WEB SERVICES Using Kernel Gateway

### Quick Hack for DS


TO deploy web services, create your GET/POST as shown here.
Make sure that your endpoint is UNIQUE across all your service. 

** IMPORTANT  ** : IT IS YOUR RESPONSIBILITY TO MAKE SURE THE END POINTS ARE UNIQUE IN ALL NOTEBOOKS
IF NOT YOU MAY GET UNEXPECTED RESULTS - Therfore see below- I prefix my end point with ws1_

* Next Edit your configuration file. Default is "default_ws_config" - it is recommended you create your own.
* Add you ipynb to your ws (see the example)
* start c

Another way is to link default_ws_config.py to a common directory and maintain *"default_ws_config"*
For ex:

[ ] mkdir ~/myWebServices
[ ] cd ~/myWebServices
[ ] cp <Your path>.../PyUtils/*
[ ] rm start_gateway.sh
[ ] ln -s <your path>.../PyUtils/start_gateway.sh .
[ ] # -> Edit your default web services
[ ] start_gateway.sh

Add all your IPython notebooks into default_ws_notebook.py
'''
;
# Out:
# ''

# %%
# %load default_ws_config.py
port=8501
notebooks=[
    "../../../notebooks/PyUtils/ws/wsex1.ipynb",
    "../../../notebooks/PyUtils/ws/wsex2.ipynb",
]

# %%
# GET /

print('''
<pre>
Hello world!!


Some Guidelines for web services we follow :
===========================================

If the parameter contains show_help or if expected parameter is not shown, then 
return the help function.
This will also help in self documenting web services.

Next, when register is called, lets plan to call regiter this service with global registration service 
with help message and SLA/auth requirements etc.
This will help to manage the registry

Lets alos log our call with parameters so that we can track some analytics.

</pre>
''')
# Out:
# <pre>
# Hello world!!
#
#
# Some Guidelines for web services we follow :
# ...
#
# If the parameter contains show_help or if expected parameter is not shown, then
# return the help function.
# This will also help in self documenting web services.
#
# Next, when register is called, lets plan to call regiter this service with global registration service
# with help message and SLA/auth requirements etc.
# This will help to manage the registry
#
# Lets alos log our call with parameters so that we can track some analytics.
#
# </pre>

# %%
# GET /redeploy

print ("Redeploying ...")
#subprocess.run("deployWS.py" , shell=True)
# Out:
# Redeploying ...

# %%
# GET /ws
print("hello world 2!")
# Out:
# hello world 2!
